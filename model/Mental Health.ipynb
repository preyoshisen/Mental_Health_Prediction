# %% [markdown]
# # Mental Health Prediction in Adolescents using Ml

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from scipy.stats import randint

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.datasets import make_classification
from sklearn.preprocessing import binarize, LabelEncoder, MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

from sklearn import metrics
from sklearn.metrics import accuracy_score, mean_squared_error, precision_recall_curve
from sklearn.model_selection import cross_val_score

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.naive_bayes import GaussianNB 

from mlxtend.classifier import StackingClassifier

data = pd.read_csv('C:/Users/prant/Downloads/survey.csv')

data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\prant\Downloads\Mental Health.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/prant/Downloads/Mental%20Health.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/c%3A/Users/prant/Downloads/Mental%20Health.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/prant/Downloads/Mental%20Health.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/prant/Downloads/Mental%20Health.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# We will OneHotEncode the state

# %%
pd.get_dummies(data['state'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 pd.get_dummies(data['state'])
#
# NameError: name 'pd' is not defined

# %% [markdown]
# This gave each state in a new column and we will have 1 in a given row and all zeroes in a single one for the given state of the example. OneHotEncoding can be used to feature one or more categorial features into numerical dummy features useful mfor training machine learning model.OneHotEncode is an ordinal feature.

# %% [markdown]
# # Cleaning

# %%
data.isna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 data.isna()
#
# NameError: name 'data' is not defined

# %% [markdown]
# To find out missing values we did the cleaning.True when there is a missing value, false otherwise

# %%
data.isna().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %% [markdown]
# Here we sum up the number of columns missing in our data set.4 columns with missing values.

# %%
data.isna().mean()
# Out:
# Timestamp                    0.000000
# Age                          0.000000
# Gender                       0.000000
# Country                      0.000000
# state                        0.409055
# self_employed                0.014297
# family_history               0.000000
# treatment                    0.000000
# work_interfere               0.209690
# no_employees                 0.000000
# remote_work                  0.000000
# tech_company                 0.000000
# benefits                     0.000000
# care_options                 0.000000
# wellness_program             0.000000
# seek_help                    0.000000
# anonymity                    0.000000
# leave                        0.000000
# mental_health_consequence    0.000000
# phys_health_consequence      0.000000
# coworkers                    0.000000
# supervisor                   0.000000
# mental_health_interview      0.000000
# phys_health_interview        0.000000
# mental_vs_physical           0.000000
# ...

# %% [markdown]
# Here we find the mean to get the percentage of missing values in each column we finf the true's and divide by the total number of columns.states and comments values are missing in the order 40% and 80%.comments is red fla g it is too high.Then we will drop the column comments as it is counterproductive to keep it

# %%
data = data.drop('comments', axis=1)

# %%
data.isna().sum()
# Out:
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# state                        515
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               264
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# dtype: int64

# %% [markdown]
# Now we will check self-employed and work interfere in the data

# %%
data
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
# ...

# %%
data['self_employed'].unique()
# Out:
# array([nan, 'Yes', 'No'], dtype=object)

# %% [markdown]
# Now we will fill out the missing values with the most common occurence

# %%
data['self_employed'].mode()
# Out:
# 0    No
# dtype: object

# %% [markdown]
# We will fill the missing values with No

# %%
data['self_employed'] = data['self_employed'].fillna('No')

# %% [markdown]
# Now we are left out with work interfere which is some sort free structure of ordinal data

# %%
data['work_interfere'].unique()
# Out:
# array(['Often', 'Rarely', 'Never', 'Sometimes', nan], dtype=object)

# %%
data['work_interfere'].mode()
# Out:
# 0    Sometimes
# dtype: object

# %%
data['work_interfere'] = data['work_interfere'].fillna('Sometimes')

# %% [markdown]
# We will see the missing values are now only in state

# %% [markdown]
# # Feature Engineering
# Feature engineering is using data and creating new features out of it

# %%
data
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL            No
# 1     2014-08-27 11:29:37   44       M   United States    IN            No
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN            No
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN            No
# 4     2014-08-27 11:30:22   31    Male   United States    TX            No
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
# ...

# %% [markdown]
# Now we will faeture some date and time from the timestamp column. We will sort it out in terms of recency as it is not of much use to us now for

# %% [markdown]
#  We will use the lambda function to each element wise in the column to get just the year that is the first four characters of the string

# %%
data['Timestamp']
# Out:
# 0       2014-08-27 11:29:31
# 1       2014-08-27 11:29:37
# 2       2014-08-27 11:29:44
# 3       2014-08-27 11:29:46
# 4       2014-08-27 11:30:22
#                ...
# 1254    2015-09-12 11:17:21
# 1255    2015-09-26 01:07:35
# 1256    2015-11-07 12:36:58
# 1257    2015-11-30 21:25:06
# 1258    2016-02-01 23:04:31
# Name: Timestamp, Length: 1259, dtype: object

# %%
data['Year'] = data['Timestamp'].apply(lambda x: np.int(x[0:4]))
data['Month'] = data['Timestamp'].apply(lambda x: np.int(x[5:7]))
data['Day'] = data['Timestamp'].apply(lambda x: np.int(x[8:10]))


data['Hour'] = data['Timestamp'].apply(lambda x: np.int(x[11:13]))
data['Minute'] = data['Timestamp'].apply(lambda x: np.int(x[14:16]))
data['Second'] = data['Timestamp'].apply(lambda x: np.int(x[17:19]))
data = data.drop('Timestamp', axis=1)
# Out:
# C:\Users\prant\AppData\Local\Temp/ipykernel_1696/1961081033.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data['Year'] = data['Timestamp'].apply(lambda x: np.int(x[0:4]))
# ...

# %%
data
# Out:
#       Age  Gender         Country state self_employed family_history  \
# 0      37  Female   United States    IL            No             No
# 1      44       M   United States    IN            No             No
# 2      32    Male          Canada   NaN            No             No
# 3      31    Male  United Kingdom   NaN            No            Yes
# 4      31    Male   United States    TX            No             No
# ...   ...     ...             ...   ...           ...            ...
# 1254   26    male  United Kingdom   NaN            No             No
# 1255   32    Male   United States    IL            No            Yes
# 1256   34    male   United States    CA            No            Yes
# 1257   46       f   United States    NC            No             No
# 1258   25    Male   United States    IL            No            Yes
#
#      treatment work_interfere    no_employees remote_work  ...  \
# 0          Yes          Often            6-25          No  ...
# ...

# %% [markdown]
# # Encoding Features

# %% [markdown]
# To find out how many unique values in each categorial column

# %% [markdown]
# data.columns will give us the numerical columns directly but here using data.select_dtypes will give us a list of all of the object columns it is a very nice way to visualize how many different values we have in each column

# %%
{column: len(data[column].unique()) for column in data.select_dtypes('object').columns}
# Out:
# {'Gender': 49,
#  'Country': 48,
#  'state': 46,
#  'self_employed': 2,
#  'family_history': 2,
#  'treatment': 2,
#  'work_interfere': 5,
#  'no_employees': 6,
#  'remote_work': 2,
#  'tech_company': 2,
#  'benefits': 3,
#  'care_options': 3,
#  'wellness_program': 3,
#  'seek_help': 3,
#  'anonymity': 3,
#  'leave': 5,
#  'mental_health_consequence': 3,
#  'phys_health_consequence': 3,
#  'coworkers': 3,
#  'supervisor': 3,
#  'mental_health_interview': 3,
#  'phys_health_interview': 3,
#  'mental_vs_physical': 3,
#  'obs_consequence': 2}

# %%
{column: list(data[column].unique()) for column in data.select_dtypes('object').columns}
